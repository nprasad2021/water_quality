# %%
import pandas as pd
import numpy as np

# %%
def preprocess_earnings(dataset_name='earnings', year_bound=2000):
    dataset_path = dataset_name + '.csv'
    df = pd.read_csv(dataset_path)
    df_mod = pd.DataFrame({'fips':df['fips'], 'county':df['county'], 'total_med':df['total_med'], 'year':df['year']})
    df.to_csv(dataset_name + '_processed.csv', index=False)
    possible_years = df['year'] >= year_bound
    df = df[possible_years]
    return df

# %%
df = preprocess_earnings()
df.head()
# Out:
#            geo_id  fips                   county  total_med  \
# 0  0500000US01001  1001  Autauga County, Alabama      31811
# 1  0500000US01003  1003  Baldwin County, Alabama      30099
# 2  0500000US01005  1005  Barbour County, Alabama      23504
# 3  0500000US01007  1007     Bibb County, Alabama      30453
# 4  0500000US01009  1009   Blount County, Alabama      30739
#
#    total_agri_fish_mine  agri_fish_hunt  mining_quarrying_oilgas_extract  \
# 0                 31793           31957                          22357.0
# 1                 33173           27342                          80938.0
# 2                 16167           14464                          27500.0
# 3                 45237           46064                          34406.0
# 4                 26909           25610                          54375.0
#
#    construction  manufacturing  wholesale_trade  ...   admin_sup  \
# 0         30347          44452            38203  ...       31250
# ...

# %%
df = pd.DataFrame({'fips':df['fips'], 'county':df['county'], 'total_med':df['total_med'], 'year':df['year']})
df.head()
# Out:
#                     county  fips  total_med  year
# 0  Autauga County, Alabama  1001      31811  2010
# 1  Baldwin County, Alabama  1003      30099  2010
# 2  Barbour County, Alabama  1005      23504  2010
# 3     Bibb County, Alabama  1007      30453  2010
# 4   Blount County, Alabama  1009      30739  2010
